# %%
import pandas as pd
import numpy as np
import datetime
from tqdm.notebook import tqdm
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import requests
from bs4 import BeautifulSoup
import time
import re
from urllib.request import urlopen
import optuna.integration.lightgbm as lgb_o
from itertools import combinations, permutations
import matplotlib.pyplot as plt

# %%
class Results:
    @staticmethod
    def scrape(race_id_list):

        """
        レース結果データをスクレイピングする関数
        Parameters:
        ----------
        race_id_list : list
            レースIDのリスト
        Returns:
        ----------
        race_results_df : pandas.DataFrame
            全レース結果データをまとめてDataFrame型にしたもの
        """
        #race_idをkeyにしてDataFrame型を格納
        race_results = {}
        for race_id in tqdm(race_id_list):
            time.sleep(1)
            try:
                url = "https://db.netkeiba.com/race/" + race_id
                # スクレイピング
                html = requests.get(url)
                html.encoding = "EUC-JP"
                # メインとなるテーブルデータを取得
                df = pd.read_html(html.text)[0]
                # 列名に半角スペースがあれば除去する
                df = df.rename(columns=lambda x: x.replace(' ', ''))
                # 天候、レースの種類、コースの長さ、馬場の状態、日付をスクレイピング
                soup = BeautifulSoup(html.text, "html.parser")
                texts = (
                    soup.find("div", attrs={"class": "data_intro"}).find_all("p")[0].text
                    + soup.find("div", attrs={"class": "data_intro"}).find_all("p")[1].text
                )
                info = re.findall(r'\w+', texts)
                for text in info:
                    if text in ["芝", "ダート"]:
                        df["race_type"] = [text] * len(df)
                    if "障" in text:
                        df["race_type"] = ["障害"] * len(df)
                    if "m" in text:
                        df["course_len"] = [int(re.findall(r"\d+", text)[-1])] * len(df)
                    if text in ["良", "稍重", "重", "不良"]:
                        df["ground_state"] = [text] * len(df)
                    if text in ["曇", "晴", "雨", "小雨", "小雪", "雪"]:
                        df["weather"] = [text] * len(df)
                    if "年" in text:
                        df["date"] = [text] * len(df)
                #馬ID、騎手IDをスクレイピング
                horse_id_list = []
                horse_a_list = soup.find("table", attrs={"summary": "レース結果"}).find_all(
                    "a", attrs={"href": re.compile("^/horse")}
                )
                for a in horse_a_list:
                    horse_id = re.findall(r"\d+", a["href"])
                    horse_id_list.append(horse_id[0])
                jockey_id_list = []
                jockey_a_list = soup.find("table", attrs={"summary": "レース結果"}).find_all(
                    "a", attrs={"href": re.compile("^/jockey")}
                )
                for a in jockey_a_list:
                    jockey_id = re.findall(r"\d+", a["href"])
                    jockey_id_list.append(jockey_id[0])
                df["horse_id"] = horse_id_list
                df["jockey_id"] = jockey_id_list
                #インデックスをrace_idにする
                df.index = [race_id] * len(df)
                race_results[race_id] = df
            #存在しないrace_idを飛ばす
            except IndexError:
                continue
            except AttributeError: #存在しないrace_idでAttributeErrorになるページもあるので追加
                continue
            #wifiの接続が切れた時などでも途中までのデータを返せるようにする
            except Exception as e:
                print(e)
                break
            #Jupyterで停止ボタンを押した時の対処
            except:
                break
        #pd.DataFrame型にして一つのデータにまとめる
        race_results_df = pd.concat([race_results[key] for key in race_results])
        return race_results_df

# %%
class HorseResults:
    @staticmethod
    def scrape(horse_id_list):
        """
        馬の過去成績データをスクレイピングする関数

        Parameters:
        ----------
        horse_id_list : list
            馬IDのリスト

        Returns:
        ----------
        horse_results_df : pandas.DataFrame
            全馬の過去成績データをまとめてDataFrame型にしたもの
        """

        #horse_idをkeyにしてDataFrame型を格納
        horse_results = {}
        for horse_id in tqdm(horse_id_list):
            time.sleep(0.5)
            try:
                url = 'https://db.netkeiba.com/horse/' + horse_id
                html = requests.get(url)
                html.encoding = "EUC-JP"
                df = pd.read_html(html.text)[3]
                soup = BeautifulSoup(html.text, "html.parser")
                race_a_list = []
                races_data = soup.find("table", attrs={"class": "db_h_race_results nk_tb_common"}).find('tbody').find_all('tr')
                for i in range(len(races_data)):
                    a_to_add = races_data[i].find('a', attrs={'href': re.compile(r'^/race/\d+/$')})
                    if a_to_add == None:
                        a_to_add = races_data[i].find('a', attrs={'title': re.compile(r'.*')})
                    race_a_list.append(a_to_add)
                race_id_list = []
                for a in race_a_list:
                    if a==None:
                        print(horse_id, 'a==none')
                        race_id_list.append(np.nan)
                        continue
                    race_id = re.findall(r"\d+", a["href"])
                    race_id_list.append(race_id[0])

                df['race_id'] = pd.Series(race_id_list)
                #受賞歴がある馬の場合、3番目に受賞歴テーブルが来るため、4番目のデータを取得する
                if df.columns[0]=='受賞歴':
                    df = pd.read_html(url)[4]
                df.index = [horse_id] * len(df)
                horse_results[horse_id] = df
            except IndexError:
                continue
            except Exception as e:
                print(e)
                break
            except:
                break

        #pd.DataFrame型にして一つのデータにまとめる        
        horse_results_df = pd.concat([horse_results[key] for key in horse_results])

        return horse_results_df

# %%
class Peds:
    @staticmethod
    def scrape(horse_id_list):
        """
        血統データをスクレイピングする関数

        Parameters:
        ----------
        horse_id_list : list
            馬IDのリスト

        Returns:
        ----------
        peds_df : pandas.DataFrame
            全血統データをまとめてDataFrame型にしたもの
        """

        peds_dict = {}
        for horse_id in tqdm(horse_id_list):
            time.sleep(1)
            try:
                url = "https://db.netkeiba.com/horse/ped/" + horse_id
                df = pd.read_html(url)[0]

                #重複を削除して1列のSeries型データに直す
                generations = {}
                for i in reversed(range(5)):
                    generations[i] = df[i]
                    df.drop([i], axis=1, inplace=True)
                    df = df.drop_duplicates()
                ped = pd.concat([generations[i] for i in range(5)]).rename(horse_id)

                peds_dict[horse_id] = ped.reset_index(drop=True)
            except IndexError:
                continue
            except Exception as e:
                print(e)
                break
            except:
                break

        #列名をpeds_0, ..., peds_61にする
        peds_df = pd.concat([peds_dict[key] for key in peds_dict], axis=1).T.add_prefix('peds_')

        return peds_df

# %%
class Return:
    @staticmethod
    def scrape(race_id_list):
        """
        払い戻し表データをスクレイピングする関数

        Parameters:
        ----------
        race_id_list : list
            レースIDのリスト

        Returns:
        ----------
        return_tables_df : pandas.DataFrame
            全払い戻し表データをまとめてDataFrame型にしたもの
        """

        return_tables = {}
        for race_id in tqdm(race_id_list):
            time.sleep(1)
            try:
                url = "https://db.netkeiba.com/race/" + race_id

                #普通にスクレイピングすると複勝やワイドなどが区切られないで繋がってしまう。
                #そのため、改行コードを文字列brに変換して後でsplitする
                f = urlopen(url)
                html = f.read()
                html = html.replace(b'<br />', b'br')
                dfs = pd.read_html(html)

                #dfsの1番目に単勝〜馬連、2番目にワイド〜三連単がある
                df = pd.concat([dfs[1], dfs[2]])

                df.index = [race_id] * len(df)
                return_tables[race_id] = df
            except IndexError:
                continue
            except AttributeError: #存在しないrace_idでAttributeErrorになるページもあるので追加
                continue
            except Exception as e:
                print(e)
                break
            except:
                break

        #pd.DataFrame型にして一つのデータにまとめる
        return_tables_df = pd.concat([return_tables[key] for key in return_tables])
        return return_tables_df

# %%
def update_data(old, new):
    """
    Parameters:
    ----------
    old : pandas.DataFrame
        古いデータ
    new : pandas.DataFrame
        新しいデータ
    """

    filtered_old = old[~old.index.isin(new.index)]
    return pd.concat([filtered_old, new])

# %%
horse_res = pd.read_pickle('beta/horse_result.pickle')
horse_id_list = horse_res.index.unique()
horse_id = horse_id_list[0]

url = 'https://db.netkeiba.com/horse/' + '2014106058'
html = requests.get(url)
html.encoding = "EUC-JP"
df = pd.read_html(html.text)[3]

# %%
soup = BeautifulSoup(html.text, "html.parser")
race_a_list = []
races_data = soup.find("table", attrs={"class": "db_h_race_results nk_tb_common"}).find('tbody').find_all('tr')
for i in range(len(races_data)):
    race_a_list.append(races_data[i].find('a', attrs={'href': re.compile(r'^/race/\d+/$')}))
race_id_list = []
for a in race_a_list:
      race_id = re.findall(r"\d+", a["href"])
      race_id_list.append(race_id[0])

df['race_id'] = pd.Series(race_id_list)
df
# Out:
#             日付    開催 天 気   R           レース名  映 像  頭 数  枠 番  馬 番  オ ッ ズ  ...
# 0   2022/01/04    園田   晴   5            C2四  NaN   10    5    5    2.9  ...  \
# 1   2021/12/16    園田   曇   6            C2三  NaN   10    3    3    3.1  ...
# 2   2021/11/13    高知   晴   5      徳島県うずしお特別  NaN   11    7    9    4.5  ...
# 3   2021/10/30    高知   晴  10      教養C新館完成特別  NaN   11    6    7    4.4  ...
# 4   2021/10/16    高知   曇  10     目指せジョッキー特別  NaN   12    4    4    3.4  ...
# 5   2021/10/02    高知   晴  10     大西輝門復帰待望特別  NaN   12    2    2    1.6  ...
# 6   2021/09/19    高知   晴  11          寒風山特別  NaN   11    6    6   14.6  ...
# 7   2021/09/05    高知   曇  11          住吉池特別  NaN   11    2    2    7.9  ...
# 8   2021/08/21    高知   雨  11            Bー2  NaN   11    8   12    5.3  ...
# 9   2021/07/31    高知   晴   5         エピカリス賞  NaN   10    3    3  113.0  ...
# 10  2021/07/17    高知   雨  11          物部川特別  NaN    9    1    1   18.4  ...
# 11  2021/07/03    高知   雨  11          竜王山特別  NaN    8    6    6    5.3  ...
# 12  2021/06/19    高知   曇   5         四万十川特別  NaN   12    5    5   23.6  ...
# 13  2021/05/29    高知   晴   5            Bー2  NaN    9    2    2    3.7  ...
# 14  2021/05/09    高知   晴  11         鏡野公園特別  NaN   10    6    6    6.7  ...
# 15  2021/04/25    高知   晴   9     モズ&グラン感謝特別  NaN   12    8   12    4.2  ...
# 16  2021/04/11    高知   晴   9           C1ー2  NaN   10    3    3    2.9  ...
# 17  2021/03/30    高知   晴  11          室津川特別  NaN    9    6    7    3.4  ...
# 18  2021/03/23    高知   晴   7      祝ゆにも誕生日特別  NaN    6    2    2    1.8  ...
# 19  2020/11/21  5東京5   晴  10  伊勢佐木特別(2勝クラス)  NaN   16    6   12   46.2  ...
# 20  2020/07/19  2福島6   晴   9   信夫山特別(2勝クラス)  NaN   16    5    9   31.1  ...
# 21  2019/07/27  1札幌1   晴  12   阿寒湖特別(2勝クラス)  NaN    9    6    6    6.6  ...
# 22  2019/06/16  3東京6   晴  10    町田特別(2勝クラス)  NaN   11    1    1    9.5  ...
# 23  2019/04/28  2東京4   晴   8      4歳以上500万下  NaN   12    5    5    4.0  ...
# 24  2019/03/02  2中山3   晴   9      4歳以上500万下  NaN   16    1    2    4.2  ...
# 25  2019/02/10  1東京6   晴   4      4歳以上500万下  NaN   16    1    2    6.4  ...
# 26  2018/08/05  1札幌4   晴   9      3歳以上500万下  NaN   14    3    4   13.7  ...
# 27  2018/02/11  1東京5   晴   8     4歳以上1000万下  NaN   16    3    5    5.6  ...
# 28  2017/12/24  5阪神8   晴   8     3歳以上1000万下  NaN   10    6    6    3.1  ...
# 29  2017/11/05  5京都2   晴   7      3歳以上500万下  NaN   15    4    7    4.0  ...
# 30  2017/10/21  4東京6   雨   7      3歳以上500万下  NaN   14    7   12    2.2  ...
# 31  2017/08/27  2札幌4   晴   8      3歳以上500万下  NaN   16    5    9    4.5  ...
# 32  2017/07/01  1函館5   曇  10    恵山特別(500万下)  NaN   15    6   10    6.0  ...
# 33  2017/05/07  2東京6   曇   1          3歳未勝利  NaN   16    1    1    2.1  ...
# 34  2017/03/11  2中京1   晴   2          3歳未勝利  NaN   12    1    1    3.4  ...
# 35  2017/02/19  1東京8   晴   2          3歳未勝利  NaN   16    1    2    6.2  ...
# 36  2016/11/05  5東京1   晴   3          2歳未勝利  NaN   14    6    9    9.1  ...
# 37  2016/10/22  4東京6   曇   5           2歳新馬  NaN   16    4    8    3.0  ...
#
#     ﾀｲﾑ 指数           通過        ペース    上り       馬体重 厩舎 ｺﾒﾝﾄ  備考    勝ち馬 (2着馬)
# 0       **          7-6   0.0-39.0   NaN   520(-3)     NaN NaN       デライーガー  \
# 1       **      5-5-3-4   0.0-39.2  39.6    523(0)     NaN NaN      シゲルジルコン
# 2       **      6-5-5-1   0.0-41.3  41.2    523(0)     NaN NaN     ミラクルヒッター
# 3       **      8-6-6-5   0.0-40.0  39.3    523(0)     NaN NaN     アポロダーウィン
# 4       **   10-10-10-4   0.0-39.6  39.3   523(+1)     NaN NaN      ケイアイマボラ
# 5       **      9-9-7-5   0.0-40.7  41.5   522(+2)     NaN NaN     セイウンデルレイ
# 6       **      8-8-9-6   0.0-39.8  39.0   520(-1)     NaN NaN       イノバティブ
# 7       **      8-6-6-3   0.0-40.1  39.8   521(+4)     NaN NaN    サンライズフォルテ
# 8       **      9-9-8-5   0.0-38.7  38.2   517(+1)     NaN NaN      ペイシャクレア
# 9       **      9-9-9-5   0.0-42.6  42.8   516(-1)     NaN NaN     クラウンシャイン
# 10      **      6-6-6-4   0.0-39.0  39.2   517(-1)     NaN NaN     ウインメテオーラ
# 11      **      2-2-2-4   0.0-40.1  40.0   518(+4)     NaN NaN     リュウノボサノバ
# 12      **      5-5-5-4   0.0-39.8  41.7    514(0)     NaN NaN     クラウンシャイン
# 13      **      6-6-5-4   0.0-40.7  40.2   514(+1)     NaN NaN    エスケイエンジェル
# 14      **      7-7-5-3   0.0-38.7  39.2   513(-4)     NaN NaN     マイネルエスパス
# 15      **      2-2-2-1   0.0-40.8  40.7   517(-3)     NaN NaN  (インバッティービレ)
# 16      **      8-8-7-7   0.0-40.2  39.9   520(-2)     NaN NaN      セヴィルロアー
# 17      **      5-5-4-4   0.0-39.3  39.1   522(-5)     NaN NaN    ジョウショーカーブ
# 18      **      5-5-4-2   0.0-39.6  39.3  527(-11)     NaN NaN       ユアマイラブ
# 19      **  13-14-12-11  31.6-37.0  37.4  538(-12)     NaN NaN    バンクオブクラウズ
# 20      **      2-2-2-4  36.4-37.2  40.0  550(+14)     NaN NaN       ヒュミドール
# 21      **      2-2-3-3  35.9-36.4  37.3   536(-8)     NaN NaN       ヒシゲッコウ
# 22      **      3-3-3-3  36.6-36.1  36.0  544(+10)     NaN NaN     ベイビーステップ
# 23      **      3-3-2-2  31.7-37.0  37.0   534(-4)     NaN NaN    (ワンダーラジャ)
# 24      **  14-14-11-11  37.1-38.7  38.2  538(-10)     NaN NaN    レオアルティメット
# 25      **   11-11-10-7  31.1-39.3  39.1   548(-2)     NaN NaN       テトラルキア
# 26      **    9-9-10-12  37.6-35.3  36.1    550(0)     NaN NaN         ゼーゲン
# 27      **      4-4-7-6  31.4-37.0  38.6  550(+14)     NaN NaN    ラテールプロミーズ
# 28      **    10-10-6-8  36.0-37.3  39.6   536(+6)     NaN NaN     ホーリーブレイズ
# 29      **   11-11-10-2  30.0-37.9  37.1    530(0)     NaN NaN     (カフジキング)
# 30      **        11-11  35.0-36.7  36.5   530(-2)     NaN NaN     ルミナリースピン
# 31      **  11-11-12-10  36.4-36.9  36.3   532(-6)     NaN NaN     グローブシアター
# 32      **  15-15-15-13  34.4-35.6  35.2   538(+2)     NaN NaN     ナイトオブナイツ
# 33      **         10-9  35.2-38.3  37.4  536(+10)     NaN NaN  (フォーティプリンス)
# 34      **      4-3-2-3  30.8-40.6  40.5   526(-2)     NaN NaN      セヴィルロアー
# 35      **  13-11-10-10  31.9-37.5  37.6  528(-14)     NaN NaN     エムオーグリッタ
# 36      **     13-13-11  36.9-35.1  34.7   542(-4)     NaN NaN      アサギリジョー
# 37      **        6-6-4  38.2-34.1  35.6    546(0)     NaN NaN     コマノインパルス
#
#        賞金       race_id
# 0     NaN  202250010405
# 1    15.0  202150121606
# 2    21.0  202154111305
# 3     9.0  202154103010
# 4     9.0  202154101610
# 5     6.0  202154100210
# 6    24.0  202154091911
# 7    24.0  202154090511
# 8    35.0  202154082111
# 9     NaN  202154073105
# 10   16.0  202154071711
# 11   32.0  202154070311
# 12   30.0  202154061905
# 13   35.0  202154052905
# 14   42.0  202154050911
# 15   70.0  202154042509
# 16    NaN  202154041109
# 17   11.0  202154033011
# 18   31.5  202154032307
# 19    NaN  202005050510
# 20    NaN  202003020609
# 21    NaN  201901010112
# 22  607.0  201905030610
# 23  750.0  201905020408
# 24   75.0  201906020309
# 25  190.0  201905010604
# 26    NaN  201801010409
# 27    NaN  201805010508
# 28    NaN  201709050808
# 29  750.0  201708050207
# 30  190.0  201705040607
# 31  190.0  201701020408
# 32  431.6  201702010510
# 33  500.0  201705020601
# 34  200.0  201707020102
# 35   75.0  201705010802
# 36    NaN  201605050103
# 37    NaN  201605040605
#
# [38 rows x 29 columns]

# %%
horse_res = pd.read_pickle('beta/horse_result.pickle')
horse_id_list = horse_res.index.unique()

for i in range(6000, len(horse_id_list), 1000):
    horse_res = HorseResults.scrape(horse_id_list[i:i+1000])
    df_prev = pd.read_pickle(f'beta/horse_data/horse_result{i}.pickle')
    horse_res.to_pickle(f'beta/horse_data_raceID_added_ver2/horse_result{i}.pickle')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/118 [00:00<?, ?it/s]

# %%
horse_data_raceID_added_ver2 = pd.read_pickle('beta/horse_data_raceID_added_ver2/horse_result0.pickle')
for i in range(1000, 37000, 1000):
    horse_data_raceID_added_ver2_temp = pd.read_pickle(f'beta/horse_data_raceID_added_ver2/horse_result{i}.pickle')
    horse_data_raceID_added_ver2 = pd.concat([horse_data_raceID_added_ver2, horse_data_raceID_added_ver2_temp])
horse_data_raceID_added_ver2.to_pickle('horse_result_raceID_added.pickle')

# %%
horse_result = pd.read_pickle('Ver1.0/horse_result.pickle')
len(horse_result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 horse_result = pd.read_pickle('Ver1.0/horse_result.pickle')
#       2 len(horse_result)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\pickle.py:179, in read_pickle(filepath_or_buffer, compression, storage_options)
#     115 """
#     116 Load pickled pandas object (or any object) from file.
#     117
#    (...)
#     176 4    4    9
#     177 """
#     178 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 179 with get_handle(
#     180     filepath_or_buffer,
#     181     "rb",
#     182     compression=compression,
#     183     is_text=False,
#     184     storage_options=storage_options,
#     185 ) as handles:
#     186     # 1) try standard library Pickle
#     187     # 2) try pickle_compat (older pandas version) to handle subclass changes
#     188     # 3) try pickle_compat with latin-1 encoding upon a UnicodeDecodeError
#     190     try:
#     191         # TypeError for Cython complaints about object.__new__ vs Tick.__new__
#     192         try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Ver1.0/horse_result.pickle'

# %%
merged = horse_data_raceID_added_ver2.merge(horse_result, how='outer', indicator=True)

only_in_horse_data_raceID_added_ver2 = merged.loc[merged['_merge'] == 'left_only']
only_in_horse_result = merged.loc[merged['_merge'] == 'right_only']
only_in_horse_data_raceID_added_ver2
# Out:
#                 日付     開催 天 気     R          レース名  映 像   頭 数  枠 番  馬 番  オ ッ ズ
# 2941    2023/05/30     高知   雨   4.0         C3ー14  NaN   9.0  8.0    8   20.1  \
# 6695    2023/05/28     高知   曇  11.0         丸塚池特別  NaN   9.0  7.0    7   60.2
# 6918    2023/05/30     高知   雨   8.0           Aー3  NaN  10.0  3.0    3    6.3
# 7114    2023/05/25     園田   曇   2.0           C3一  NaN  12.0  1.0    1   33.0
# 7599    2023/06/01     浦和   晴  11.0  ’23武蔵国OP(OP)  NaN   8.0  4.0    4   22.3
# ...            ...    ...  ..   ...           ...  ...   ...  ...  ...    ...
# 782830  2023/05/27  1京都11   晴   5.0         3歳未勝利  NaN  13.0  4.0    5    3.6
# 782834  2023/05/27  1京都11   晴   5.0         3歳未勝利  NaN  13.0  7.0   10   18.6
# 782866  2023/05/26     園田   曇   9.0          3歳AB  NaN   9.0  3.0    3   16.9
# 782906  2023/05/27  1京都11   晴   4.0         3歳未勝利  NaN  18.0  6.0   12  243.5
# 782913  2023/05/28  1京都12   晴   5.0         3歳未勝利  NaN  17.0  3.0    5  107.8
#
#         ...  オッズ  人気   着順  斤量   馬場 馬場指数 ﾀｲﾑ指数 厩舎ｺﾒﾝﾄ  勝ち馬(2着馬)     _merge
# 2941    ...  NaN NaN  NaN NaN  NaN  NaN   NaN    NaN       NaN  left_only
# 6695    ...  NaN NaN  NaN NaN  NaN  NaN   NaN    NaN       NaN  left_only
# 6918    ...  NaN NaN  NaN NaN  NaN  NaN   NaN    NaN       NaN  left_only
# 7114    ...  NaN NaN  NaN NaN  NaN  NaN   NaN    NaN       NaN  left_only
# 7599    ...  NaN NaN  NaN NaN  NaN  NaN   NaN    NaN       NaN  left_only
# ...     ...  ...  ..  ...  ..  ...  ...   ...    ...       ...        ...
# 782830  ...  NaN NaN  NaN NaN  NaN  NaN   NaN    NaN       NaN  left_only
# 782834  ...  NaN NaN  NaN NaN  NaN  NaN   NaN    NaN       NaN  left_only
# 782866  ...  NaN NaN  NaN NaN  NaN  NaN   NaN    NaN       NaN  left_only
# 782906  ...  NaN NaN  NaN NaN  NaN  NaN   NaN    NaN       NaN  left_only
# 782913  ...  NaN NaN  NaN NaN  NaN  NaN   NaN    NaN       NaN  left_only
#
# [2513 rows x 44 columns]

# %%
only_in_horse_data_raceID_added_ver2.to_pickle('horse_result_raceID_added.pickle')

# %%
import pandas as pd
horse_res = pd.read_pickle('beta/horse_result.pickle')
horse_id_list = horse_res.index.unique()

horse_id_list[6357]
horse_res = HorseResults.scrape(horse_id_list[6355:6360])
    # horse_res.to_pickle('beta/horse_data_raceID_added/horse_result.pickle')

# %%
df = pd.read_pickle('beta/horse_data_raceID_added/horse_result0.pickle')
for i in range(10000, 37000, 1000):
    d = pd.read_pickle(f'beta/horse_data_raceID_added/horse_result{i}.pickle')
    df = pd.concat([df, d])
df.columns = df.columns.str.replace(' ', '')
df
# Out:
#                     日付     開催 天気     R        レース名  映像    頭数   枠番  馬番   オッズ
# 2015100713  2020/11/21   5阪神5  晴  11.0  アンドロメダS(L) NaN  15.0  1.0   1  68.8  \
# 2015100713  2020/10/24   4新潟5  雨  11.0   新潟牝馬S(OP) NaN  13.0  6.0   8  12.1
# 2015100713  2020/09/06   3新潟8  晴  11.0    新潟記念(G3) NaN  18.0  7.0  15  75.8
# 2015100713  2020/08/02   1札幌4  晴  11.0   クイーンS(G3) NaN  14.0  6.0  10  16.8
# 2015100713  2020/06/14   3阪神4  曇  11.0  マーメイドS(G3) NaN  16.0  4.0   8  10.1
# ...                ...    ... ..   ...         ...  ..   ...  ...  ..   ...
# 2020100674  2023/02/05  1中京12  晴   6.0        3歳新馬 NaN  15.0  5.0   8  20.3
# 2020106815  2023/05/14   1京都8  曇   4.0       3歳未勝利 NaN  10.0  5.0   5  27.1
# 2020106815  2023/02/26   1阪神6  曇   5.0       3歳未勝利 NaN  17.0  7.0  14  75.0
# 2020106815  2023/02/12   1阪神2  晴   6.0       3歳未勝利 NaN  12.0  1.0   1  23.5
# 2020106815  2023/01/22   1小倉4  曇   5.0        3歳新馬 NaN  16.0  7.0  14  12.4
#
#             ...  ﾀｲﾑ指数           通過        ペース    上り      馬体重 厩舎ｺﾒﾝﾄ  備考
# 2015100713  ...     **  12-11-11-12  35.4-35.5  35.5  428(-6)    NaN NaN  \
# 2015100713  ...     **      6-7-9-7  36.3-35.6  37.0  434(+6)    NaN NaN
# 2015100713  ...     **          4-5  36.8-33.1  33.5  428(+4)    NaN NaN
# 2015100713  ...     **  10-10-10-11  34.8-36.0  35.1  424(+4)    NaN NaN
# 2015100713  ...     **    10-10-8-8  36.3-36.5  36.8  420(-4)    NaN NaN
# ...         ...    ...          ...        ...   ...      ...    ...  ..
# 2020100674  ...     **      9-10-10  37.4-34.5  34.2   400(0)    NaN NaN
# 2020106815  ...     **     10-9-9-9  35.8-37.7  37.1  464(+4)    NaN NaN
# 2020106815  ...     **        13-13  36.5-35.0  34.8  460(-2)    NaN NaN
# 2020106815  ...     **      2-1-1-1  35.3-36.6  37.6  462(-2)    NaN NaN
# 2020106815  ...     **      5-6-7-7  37.5-36.0  36.2   464(0)    NaN NaN
#
#             勝ち馬(2着馬)    賞金       race_id
# 2015100713  アドマイヤビルゴ   NaN  202009050511
# 2015100713  ウラヌスチャーム   NaN  202004040511
# 2015100713     ブラヴァス   NaN  202004030811
# 2015100713   レッドアネモス   NaN  202001010411
# 2015100713    サマーセント   NaN  202009030411
# ...              ...   ...           ...
# 2020100674   タイキバルドル  62.0  202307011206
# 2020106815  ニホンピロアリー   NaN  202308010804
# 2020106815   ルクスドヌーヴ   NaN  202309010605
# 2020106815   レシプロシティ   NaN  202309010206
# 2020106815   ベレザニーニャ   NaN  202310010405
#
# [499009 rows x 29 columns]

# %%
for i in range(0, 37000, 1000):
    d1 = pd.read_pickle(f'beta/horse_data/horse_result{i}.pickle')
    d2 = pd.read_pickle(f'beta/horse_data_raceID_added/horse_result{i}.pickle')
    if len(d2) == len(d1):
        print(i)

# %%
df = pd.read_pickle('beta/horse_data_raceID_added/horse_result0.pickle')
for i in range(10000, 37000, 1000):
    d = pd.read_pickle(f'beta/horse_data_raceID_added/horse_result{i}.pickle')
    df = pd.concat([df, d])
df.columns = df.columns.str.replace(' ', '')

df2 = pd.read_pickle('beta/horse_result.pickle')
df = df.reset_index()
df2 = df2.reset_index()
df2 = pd.merge(df2, df, on=list(df2.columns), how='left')
# Out:
#              index          日付     開催 天気     R        レース名  映像    頭数   枠番  馬番
# 0       2015100713  2020/11/21   5阪神5  晴  11.0  アンドロメダS(L) NaN  15.0  1.0   1  \
# 1       2015100713  2020/10/24   4新潟5  雨  11.0   新潟牝馬S(OP) NaN  13.0  6.0   8
# 2       2015100713  2020/09/06   3新潟8  晴  11.0    新潟記念(G3) NaN  18.0  7.0  15
# 3       2015100713  2020/08/02   1札幌4  晴  11.0   クイーンS(G3) NaN  14.0  6.0  10
# 4       2015100713  2020/06/14   3阪神4  曇  11.0  マーメイドS(G3) NaN  16.0  4.0   8
# ...            ...         ...    ... ..   ...         ...  ..   ...  ...  ..
# 780402  2020100674  2023/02/05  1中京12  晴   6.0        3歳新馬 NaN  15.0  5.0   8
# 780403  2020106815  2023/05/14   1京都8  曇   4.0       3歳未勝利 NaN  10.0  5.0   5
# 780404  2020106815  2023/02/26   1阪神6  曇   5.0       3歳未勝利 NaN  17.0  7.0  14
# 780405  2020106815  2023/02/12   1阪神2  晴   6.0       3歳未勝利 NaN  12.0  1.0   1
# 780406  2020106815  2023/01/22   1小倉4  曇   5.0        3歳新馬 NaN  16.0  7.0  14
#
#         ...  ﾀｲﾑ指数           通過        ペース    上り      馬体重 厩舎ｺﾒﾝﾄ  備考
# 0       ...     **  12-11-11-12  35.4-35.5  35.5  428(-6)    NaN NaN  \
# 1       ...     **      6-7-9-7  36.3-35.6  37.0  434(+6)    NaN NaN
# 2       ...     **          4-5  36.8-33.1  33.5  428(+4)    NaN NaN
# 3       ...     **  10-10-10-11  34.8-36.0  35.1  424(+4)    NaN NaN
# 4       ...     **    10-10-8-8  36.3-36.5  36.8  420(-4)    NaN NaN
# ...     ...    ...          ...        ...   ...      ...    ...  ..
# 780402  ...     **      9-10-10  37.4-34.5  34.2   400(0)    NaN NaN
# 780403  ...     **     10-9-9-9  35.8-37.7  37.1  464(+4)    NaN NaN
# 780404  ...     **        13-13  36.5-35.0  34.8  460(-2)    NaN NaN
# 780405  ...     **      2-1-1-1  35.3-36.6  37.6  462(-2)    NaN NaN
# 780406  ...     **      5-6-7-7  37.5-36.0  36.2   464(0)    NaN NaN
#
#         勝ち馬(2着馬)    賞金       race_id
# 0       アドマイヤビルゴ   NaN  202009050511
# 1       ウラヌスチャーム   NaN  202004040511
# 2          ブラヴァス   NaN  202004030811
# 3        レッドアネモス   NaN  202001010411
# 4         サマーセント   NaN  202009030411
# ...          ...   ...           ...
# 780402   タイキバルドル  62.0  202307011206
# 780403  ニホンピロアリー   NaN  202308010804
# 780404   ルクスドヌーヴ   NaN  202309010605
# 780405   レシプロシティ   NaN  202309010206
# 780406   ベレザニーニャ   NaN  202310010405
#
# [780407 rows x 30 columns]

# %%
horse_id = '2015106464'
url = 'https://db.netkeiba.com/horse/' + horse_id
html = requests.get(url)
html.encoding = "EUC-JP"
df = pd.read_html(html.text)[3]
soup = BeautifulSoup(html.text, "html.parser")
race_a_list = []
races_data = soup.find("table", attrs={"class": "db_h_race_results nk_tb_common"}).find('tbody').find_all('tr')
for i in range(len(races_data)):
    a_to_add = races_data[i].find('a', attrs={'href': re.compile(r'^/race/\d+/$')})
    if a_to_add == None:
        a_to_add = races_data[i].find('a', attrs={'title': re.compile(r'.*')})
    race_a_list.append(a_to_add)
race_id_list = []
for a in race_a_list:
    if a==None:
        print(horse_id, 'a==none')
        race_id_list.append(np.nan)
        continue
    race_id = re.findall(r"\d+", a["href"])
    race_id_list.append(race_id[0])

for i in race_id_list:
    if i==np.nan: print(i)

# %%
ls = df2[df2['race_id'].isnull()]['index'].unique()

for i in range(0, len(ls), 1000):
    horse_res = HorseResults.scrape(ls[i:i+1000])
    # horse_res.to_pickle(f'beta/horse_data_raceID_added/horse_result_supplement{i}.pickle')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 2015101621 a==none
# 2014105785 a==none
# 2013102955 a==none
# 2013102955 a==none
# 2014105304 a==none
# 2015104624 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2014106191 a==none
# 2013101999 a==none
# 2013101999 a==none
# 2010100855 a==none
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 ls = df2[df2['race_id'].isnull()]['index'].unique()
#       3 for i in range(0, len(ls), 1000):
# ----> 4     horse_res = HorseResults.scrape(ls[i:i+1000])
#       5     # horse_res.to_pickle(f'beta/horse_data_raceID_added/horse_result_supplement{i}.pickle')
#
# Cell In[2], line 21, in HorseResults.scrape(horse_id_list)
#      19 horse_results = {}
#      20 for horse_id in tqdm(horse_id_list):
# ---> 21     time.sleep(0.5)
#      22     try:
#      23         url = 'https://db.netkeiba.com/horse/' + horse_id
#
# KeyboardInterrupt:

# %%
url = 'https://db.netkeiba.com/horse/'+horse_id_list[43]
html = requests.get(url)
html.encoding = "EUC-JP"
df = pd.read_html(html.text)[3]
soup = BeautifulSoup(html.text, "html.parser")
race_a_list = []
races_data = soup.find("table", attrs={"class": "db_h_race_results nk_tb_common"}).find('tbody').find_all('tr')
for i in range(len(races_data)):
    race_a_list.append(races_data[i].find('a', attrs={'href': re.compile(r'^/race/\d+/$')}))
race_id_list = []
for a in race_a_list:
      if a==None:
           race_id_list.append(np.nan)
           continue
      race_id = re.findall(r"\d+", a["href"])
      race_id_list.append(race_id)

df['race_id'] = pd.Series(race_id_list)
df
# Out:
#             日付    開催  天 気     R            レース名  映 像  頭 数  枠 番  馬 番  オ ッ ズ
# 0   2020/12/13  シャティ  NaN   NaN     香港スプリント(G1)  NaN   14  NaN    6    8.9  \
# 1   2020/05/16  2東京7    雨  11.0   京王杯スプリングC(G2)  NaN   13  7.0   10    3.5
# 2   2020/03/29  1中京8    晴  11.0       高松宮記念(G1)  NaN   18  5.0    9    3.8
# 3   2020/03/07  2中山3    曇  11.0  夕刊フジオーシャンS(G3)  NaN   16  1.0    1    2.5
# 4   2019/09/29  4中山9    曇  11.0    スプリンターズS(G1)  NaN   16  4.0    8    2.9
# 5   2019/09/08  4阪神2    晴  11.0   産経賞セントウルS(G2)  NaN   13  5.0    7    2.7
# 6   2019/08/25  2札幌4    晴  11.0     キーンランドC(G3)  NaN   16  4.0    7    4.7
# 7   2019/06/16  1函館2   小雨  11.0    函館スプリントS(G3)  NaN    7  8.0   13    1.8
# 8   2019/05/11  2東京7    晴  11.0   京王杯スプリングC(G2)  NaN   15  5.0    9    3.6
# 9   2019/02/03  1東京4    晴  11.0       東京新聞杯(G3)  NaN   15  3.0    5    3.6
# 10  2018/11/24  5東京7    晴  11.0      キャピタルS(OP)  NaN   14  6.0    9    3.9
# 11  2018/05/06  2東京6    晴  11.0     NHKマイルC(G1)  NaN   18  4.0    7    2.6
# 12  2018/04/14  2阪神7    雨  11.0     アーリントンC(G3)  NaN   13  5.0    6    3.1
# 13  2017/12/17  5阪神6    晴  11.0  朝日フューチュリティ(G1)  NaN   16  2.0    3    3.9
# 14  2017/11/04  5東京1    曇  11.0      京王杯2歳S(G2)  NaN   11  1.0    1    1.8
# 15  2017/09/23  4阪神6    曇   9.0       ききょうS(OP)  NaN   11  8.0   11    1.8
# 16  2017/08/20  2札幌2    晴   9.0      クローバー賞(OP)  NaN   11  8.0   10    1.7
# 17  2017/07/29  1札幌1    曇   5.0            2歳新馬  NaN    9  8.0    8    4.0
#
#     ...  ﾀｲﾑ 指数     通過        ペース    上り       馬体重 厩舎 ｺﾒﾝﾄ  備考    勝ち馬 (2着馬)
# 0   ...     NaN    NaN        NaN   NaN        計不     NaN NaN          NaN  \
# 1   ...      **    4-5  35.2-33.1  33.3   516(+2)     NaN NaN     ダノンスマッシュ
# 2   ...      **    8-9  34.2-34.5  34.5   514(-6)     NaN NaN    モズスーパーフレア
# 3   ...      **    9-6  33.1-34.3  34.4   520(+6)     NaN NaN     ダノンスマッシュ
# 4   ...      **   11-8  32.8-34.3  33.5   514(-2)     NaN NaN  (モズスーパーフレア)
# 5   ...      **    7-7  33.0-33.7  33.2   516(-4)     NaN NaN    (ファンタジスト)
# 6   ...      **  12-12  33.2-36.0  34.9   520(+2)     NaN NaN     ダノンスマッシュ
# 7   ...      **    5-5  34.4-34.0  33.5    518(0)     NaN NaN    カイザーメランジェ
# 8   ...      **    7-6  34.2-33.9  33.1   518(-8)     NaN NaN       (リナーテ)
# 9   ...      **    5-5  34.5-34.7  34.2  526(+10)     NaN NaN     インディチャンプ
# 10  ...      **    7-9  36.1-33.4  32.4   516(+6)     NaN NaN      グァンチャーレ
# 11  ...      **  11-12  34.4-34.8  35.1    510(0)     NaN NaN    ケイアイノーテック
# 12  ...      **    9-9  34.5-34.7  34.2   510(-8)     NaN NaN  (パクスアメリカーナ)
# 13  ...      **    7-7  35.2-34.0  34.0   518(+2)     NaN NaN     ダノンプレミアム
# 14  ...      **    6-7  36.0-33.8  33.2   516(+4)     NaN NaN       (カシアス)
# 15  ...      **    9-7  33.5-36.5  35.2  512(-10)     NaN NaN   (バーニングペスカ)
# 16  ...      **  7-8-7  30.8-36.0  35.6   522(+6)     NaN NaN      ダブルシャープ
# 17  ...      **  1-1-1  30.4-35.3  35.3    516(0)     NaN NaN      (キルロード)
#
#          賞金         race_id
# 0       NaN             NaN
# 1       NaN  [202005020711]
# 2       NaN  [202007010811]
# 3    1008.0  [202006020311]
# 4   11344.4  [201906040911]
# 5    5993.8  [201909040211]
# 6    1616.2  [201901020411]
# 7     986.7  [201902010211]
# 8    6013.4  [201905020711]
# 9     390.0  [201905010411]
# 10    929.0  [201805050711]
# 11      NaN  [201805020611]
# 12   3846.9  [201809020711]
# 13   1816.4  [201709050611]
# 14   3839.2  [201705050111]
# 15   1623.8  [201709040609]
# 16    647.2  [201701020209]
# 17    700.0  [201701010105]
#
# [18 rows x 29 columns]

# %%
horse_peds = pd.DataFrame()
for i in range(0, len(horse_id_list), 1000):
    peds_temp = pd.read_pickle('horse_peds'+str(i)+'.pickle')
    horse_peds = pd.concat([horse_peds, peds_temp])
horse_peds.to_pickle('horse_peds.pickle')
horse_peds.to_csv('horse_peds.csv')

# %%
for i in range(0, len(horse_id_list), 1000):
    d = pd.read_pickle('horse_result'+str(i)+'.pickle')
    if len(d.index.unique()) != 1000: print(i, len(d.index.unique()))
# Out:
# 36000 118

# %%
# soup = BeautifulSoup(html.content, 'html.parser')
# soup.find('table', attrs={'class': 'blood_table'}).find_all('a')
df = pd.read_html(url)[0]
peds_dict = {}
horse_id = '2015100713'
#重複を削除して1列のSeries型データに直す
generations = {}
for i in reversed(range(5)):
    generations[i] = df[i]
    df.drop([i], axis=1, inplace=True)
    df = df.drop_duplicates()
ped = pd.concat([generations[i] for i in range(5)]).rename(horse_id)

peds_dict[horse_id] = ped.reset_index(drop=True)

peds_dict
peds_df = pd.concat([peds_dict[key] for key in peds_dict], axis=1).T.add_prefix('peds_')
peds_df
# Out:
#                                      peds_0                            peds_1
# 2015100713  ステイゴールド 1994 黒鹿毛 [血統][産駒] Halo系  ピノブラン 2007 芦毛 [血統][産駒] FNo.[2-n]  \
#
#                                                    peds_2
# 2015100713  サンデーサイレンス Sunday Silence(米) 1986 青鹿毛 [血統][産駒]  \
#
#                                 peds_3                 peds_4
# 2015100713  ゴールデンサッシュ 1988 栗毛 [血統][産駒]  クロフネ 1998 芦毛 [血統][産駒]  \
#
#                                 peds_5                  peds_6
# 2015100713  フェートデュヴァン 2000 鹿毛 [血統][産駒]  Halo 1969 黒鹿毛 [血統][産駒]  \
#
#                                    peds_7                            peds_8
# 2015100713  Wishing Well 1975 鹿毛 [血統][産駒]  ディクタス Dictus(仏) 1967 栗毛 [血統][産駒]  \
#
#                               peds_9  ...    peds_52 peds_53 peds_54 peds_55
# 2015100713  ダイナサッシュ 1979 鹿毛 [血統][産駒]  ...  Icecapade     コレラ  メジロアサマ    シエリル  \
#
#            peds_56  peds_57          peds_58       peds_59     peds_60
# 2015100713    リマンド  メジロアイリス  Northern Dancer  Flaming Page  Riva Ridge  \
#
#                peds_61
# 2015100713  Gliding By
#
# [1 rows x 62 columns]

# %%
r = pd.read_pickle('beta/race.pickle')
r[r['horse_id']=='2015101621']
# Out:
#               着順  枠番  馬番         馬名  性齢    斤量    騎手     タイム   着差   単勝   人気
# 201701010105   1   8   8  タワーオブロンドン  牡2  54.0  ルメール  1:30.4  NaN  4.0  2.0  \
# 201701020209   2   8  10  タワーオブロンドン  牡2  54.0  ルメール  1:30.9  3/4  1.7  1.0
# 201705050111   1   1   1  タワーオブロンドン  牡2  55.0  ルメール  1:21.9  NaN  1.8  1.0
# 201709040609   1   8  11  タワーオブロンドン  牡2  54.0  ルメール  1:21.7  NaN  1.8  1.0
# 201709050611   3   2   3  タワーオブロンドン  牡2  55.0  ルメール  1:33.9   クビ  3.9  2.0
# 201805020611  12   4   7  タワーオブロンドン  牡3  57.0  ルメール  1:33.8   クビ  2.6  1.0
# 201805050711   2   6   9  タワーオブロンドン  牡3  56.0  ビュイッ  1:32.6   クビ  3.9  2.0
# 201809020711   1   5   6  タワーオブロンドン  牡3  56.0  ルメール  1:33.4  NaN  3.1  1.0
# 201901020411   2   4   7  タワーオブロンドン  牡4  58.0  ルメール  1:09.3  3/4  4.7  2.0
# 201902010211   3   8  13  タワーオブロンドン  牡4  58.0   レーン  1:08.6   クビ  1.8  1.0
# 201905010411   5   3   5  タワーオブロンドン  牡4  57.0  ルメール  1:32.3   ハナ  3.6  2.0
# 201905020711   1   5   9  タワーオブロンドン  牡4  56.0   レーン  1:19.4  NaN  3.6  1.0
# 201909040211   1   5   7  タワーオブロンドン  牡4  57.0  ルメール  1:06.7  NaN  2.7  1.0
# 202005020711   8   7  10  タワーオブロンドン  牡5  58.0  ルメール  1:20.4   クビ  3.5  1.0
# 202006020311   3   1   1  タワーオブロンドン  牡5  58.0  ルメール  1:08.1    3  2.5  2.0
# 202007010811  12   5   9  タワーオブロンドン  牡5  57.0  福永祐一  1:09.8  3/4  3.8  1.0
#
#                    馬体重       調教師  course_len weather race_type ground_state
# 201701010105    516(0)  [東] 藤沢和雄        1500       曇         芝            良  \
# 201701020209   522(+6)  [東] 藤沢和雄        1500       晴         芝            良
# 201705050111   516(+4)  [東] 藤沢和雄        1400       曇         芝            良
# 201709040609  512(-10)  [東] 藤沢和雄        1400       曇         芝            良
# 201709050611   518(+2)  [東] 藤沢和雄        1600       晴         芝            良
# 201805020611    510(0)  [東] 藤沢和雄        1600       晴         芝            良
# 201805050711   516(+6)  [東] 藤沢和雄        1600       晴         芝            良
# 201809020711   510(-8)  [東] 藤沢和雄        1600       雨         芝            良
# 201901020411   520(+2)  [東] 藤沢和雄        1200       晴         芝           稍重
# 201902010211    518(0)  [東] 藤沢和雄        1200      小雨         芝           稍重
# 201905010411  526(+10)  [東] 藤沢和雄        1600       晴         芝            良
# 201905020711   518(-8)  [東] 藤沢和雄        1400       晴         芝            良
# 201909040211   516(-4)  [東] 藤沢和雄        1200       晴         芝            良
# 202005020711   516(+2)  [東] 藤沢和雄        1400       雨         芝           稍重
# 202006020311   520(+6)  [東] 藤沢和雄        1200       曇         芝            良
# 202007010811   514(-6)  [東] 藤沢和雄        1200       晴         芝            重
#
#                      date    horse_id jockey_id
# 201701010105   2017年7月29日  2015101621     05339
# 201701020209   2017年8月20日  2015101621     05339
# 201705050111   2017年11月4日  2015101621     05339
# 201709040609   2017年9月23日  2015101621     05339
# 201709050611  2017年12月17日  2015101621     05339
# 201805020611    2018年5月6日  2015101621     05339
# 201805050711  2018年11月24日  2015101621     05495
# 201809020711   2018年4月14日  2015101621     05339
# 201901020411   2019年8月25日  2015101621     05339
# 201902010211   2019年6月16日  2015101621     05585
# 201905010411    2019年2月3日  2015101621     05339
# 201905020711   2019年5月11日  2015101621     05585
# 201909040211    2019年9月8日  2015101621     05339
# 202005020711   2020年5月16日  2015101621     05339
# 202006020311    2020年3月7日  2015101621     05339
# 202007010811   2020年3月29日  2015101621     01014
